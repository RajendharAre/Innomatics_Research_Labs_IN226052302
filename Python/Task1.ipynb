# %% [markdown]
# <a href="https://colab.research.google.com/github/RajendharAre/Innomatics_Research_Labs_GenAI_FEB/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. User Login Check

# %%
username = "admin"
password = "1234"

input_username = input("Enter youur Username: ")
input_password = input("Enter your Password: ")

if input_username == username and input_password == password:
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter youur Username: admin
# Enter your Password: 1234
# Login Successful

# %% [markdown]
# ## 2. Pass / Fail Analyzer

# %%
marks = [45, 78, 90, 33, 60]
pass_cnt = 0
fail_cnt = 0
for mark in marks:
   if mark >= 50:
    pass_cnt += 1
   else:
    fail_cnt += 1

print("Pass Count: ", pass_cnt)
print("Fail Count: ", fail_cnt)
# Out:
# Pass Count:  3
# Fail Count:  2

# %% [markdown]
# ## 3. Simple Data Cleaner

# %%
names = [" Alice ", "bob", " CHARLIE "]
clean_naames = [name.strip().lower() for name in names]
print(clean_naames)
# Out:
# ['alice', 'bob', 'charlie']

# %% [markdown]
# ## 4. Message Length Analyzer

# %%
messages = ["Hi", "Welcome to the platform", "OK"]
for msg in messages:
    length = len(msg)
    if length > 10:
      print(f"mesage: {msg} of length: {length}. (flag :message is longer than 10)!! ")
    else:
      print(f"mesage: {msg} of length: {length}. OK")
# Out:
# mesage: Hi of length: 2. OK
# mesage: Welcome to the platform of length: 23. (flag :message is longer than 10)!!
# mesage: OK of length: 2. OK

# %% [markdown]
# ## 5. Error Message Detector

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]
err_cnt = 0
for log in logs:
    if log == "ERROR":
        err_cnt += 1

print("Error Count: ", err_cnt)
# Out:
# Error Count:  2
